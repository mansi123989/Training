# %% [markdown]
# **pipelining**

# %%
data = pd.read_csv("laptop_data.csv")
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
x = data[['Company' , 'TypeName']]
y = data['Price']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=3)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression

# %%
transformer1 = ColumnTransformer(
    transformers=[
        
        ('trn1', OneHotEncoder(drop='first', sparse_output=False), ['Company', 'TypeName'])
    ],
    remainder='passthrough'
)

# %%
pipe = Pipeline(
    steps=[
        ('tran', transformer1),
        ('ir', LinearRegression())
    ]
)

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tran',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trn1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['Company', 'TypeName'])])),
#                 ('ir', LinearRegression())])

# %%
x_train
# Out:
#       Unnamed: 0  Company     TypeName  Inches             ScreenResolution  \
# 189          189     Dell     Notebook    17.3            Full HD 1920x1080
# 108          108      MSI       Gaming    15.6            Full HD 1920x1080
# 464          464   Lenovo     Notebook    15.6            Full HD 1920x1080
# 1212        1212      MSI       Gaming    17.3  IPS Panel Full HD 1920x1080
# 447          447     Dell  Workstation    15.6            Full HD 1920x1080
# ...          ...      ...          ...     ...                          ...
# 789          789     Dell       Gaming    15.6            Full HD 1920x1080
# 256          256       HP     Notebook    15.6                     1366x768
# 968          968     Dell       Gaming    17.3  IPS Panel Full HD 1920x1080
# 952          952  Toshiba     Notebook    13.3            Full HD 1920x1080
# 1273        1273       HP     Notebook    15.6                     1366x768
#
#                                Cpu   Ram                         Memory  \
# 189     Intel Core i7 8550U 1.8GHz   8GB           128GB SSD +  1TB HDD
# 108    Intel Core i7 7700HQ 2.8GHz  16GB           256GB SSD +  1TB HDD
# 464    Intel Core i7 7820HQ 2.9GHz   8GB                      256GB SSD
# 1212   Intel Core i7 6700HQ 2.6GHz  16GB           256GB SSD +  1TB HDD
# 447    Intel Xeon E3-1505M V6 3GHz   8GB  64GB Flash Storage +  1TB HDD
# ...                            ...   ...                            ...
# 789    Intel Core i5 7300HQ 2.5GHz   8GB                      256GB SSD
# 256   AMD A6-Series A6-9220 2.5GHz   8GB                      128GB SSD
# 968    Intel Core i7 7700HQ 2.8GHz  32GB           256GB SSD +  1TB HDD
# 952     Intel Core i5 6200U 2.3GHz   8GB                      256GB SSD
# 1273    Intel Core i7 6500U 2.5GHz   6GB                        1TB HDD
#
#                              Gpu       OpSys  Weight  Ram1
# 189               AMD Radeon 530  Windows 10   2.8kg     8
# 108   Nvidia GeForce GTX 1050 Ti  Windows 10   2.2kg    16
# 464         Nvidia Quadro M2200M  Windows 10  2.67kg     8
# 1212     Nvidia GeForce GTX 1060  Windows 10  2.43kg    16
# 447           Nvidia Quadro M620  Windows 10  2.23kg     8
# ...                          ...         ...     ...   ...
# 789      Nvidia GeForce GTX 1050  Windows 10  2.62kg     8
# 256       AMD Radeon R4 Graphics  Windows 10  1.91kg     8
# 968      Nvidia GeForce GTX 1070  Windows 10  4.42kg    32
# 952        Intel HD Graphics 520   Windows 7   1.2kg     8
# 1273          AMD Radeon R5 M330  Windows 10  2.19kg     6
#
# [912 rows x 12 columns]
