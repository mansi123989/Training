# %%
dict = { 'anu' : 50,
         'manu':60,
          'priya':78}

# %% [markdown]
# **SERIES**

# %%
import pandas as p
seriesd = p.Series(dict)
seriesd
# Out:
# anu      50
# manu     60
# priya    78
# dtype: int64

# %%
import pandas as p
data = p.read_csv('matches.csv')
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
series = p.Series( data['winner'])
series.dtype
# Out:
# dtype('O')

# %%
data['team'] = data['team1'].str.split(' ').apply(lambda x:x[0:-1])

# %% [markdown]
# **data visulization using mataplotlib.pyplot**

# %%
import matplotlib.pyplot as plt

# %%
year = ['2021 ' ,'2022','2023']
price = [340 , 450,300]
plt.plot(year,price)

# %%
import pandas as p
data = p.read_csv('matches.csv')
(data['toss_winner'] == data['winner'] ).sum()

# %%
(( data['winner'] == 'Chennai Super Kings')	& (data['city'] == 'Kolkata')).sum()

# %%
import pandas as p
data_mov = p.read_csv('movies.csv')
data_mov
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
(data_mov['vote_average'] > 7.5).sum()
# Out:
# 271

# %%
((data_mov['vote_average'] > 8 ) & (data_mov['vote_count'] >10000)).sum()
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import pandas as p
data_mov = p.read_csv('movies.csv')
y = data_mov['popularity'][0:15]
x = data_mov['original_title'][0:15]
plt.figure(figsize = (15,10))
plt.xticks(rotation = 45)
plt.xlabel("movie name")
plt.ylabel("popularity")
plt.legend('best')
plt.bar( x,y,width = 1,edgecolor = "black")
# Out:
# <BarContainer object of 15 artists>

# %%
x1 = data_mov['budget'][0:50]
y1 = data_mov['popularity'][0:50]
plt.scatter(x1,y1)

# %%
#c = data_mov['director'].value_counts()[0:6]
d = [ ' a','b','c','d','e','f']
c = [2,3,4,8,5,1]

plt.pie(c , labels = d)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f7863eec60>,
# ...
#  [Text(1.0592090145724589, 0.2967764536624172, ' a'),
#   Text(0.6343483488390105, 0.8986668861848762, 'b'),
#   Text(-0.3683675860458567, 1.0364870098321293, 'c'),
#   Text(-1.0089324129244073, -0.43824124195531106, 'd'),
#   Text(0.6343483909086426, -0.8986668564888862, 'e'),
#   Text(1.0897545437648157, -0.14978329127088505, 'f')])

# %%
plt.boxplot(data_mov['budget'][::100])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f7864b1010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f7864b14f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f7864b0d40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f7864b1910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f7864b1bb0>],
#  'means': []}
