# %% [markdown]
# **Encoding**

# %% [markdown]
# * encoding refers to changing categorical data into numerical data
# * types of encoding :- 1. ordinal encoding 2. label encoding 3. onehot encoding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('laptop_data.csv')
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
x = data[['Company']]
y = data[['TypeName']]
x_train , x_test, y_train, y_test = train_test_split(x , y ,test_size = 0.33 , random_state=2)

# %% [markdown]
# * 1. Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
en = OrdinalEncoder()
encode = en.fit_transform(x_train)
pd.DataFrame(encode, columns=['Company'])
# Out:
#      Company
# 0        4.0
# 1        7.0
# 2       10.0
# 3        4.0
# 4        7.0
# ..       ...
# 868      0.0
# 869      2.0
# 870      0.0
# 871      9.0
# 872      7.0
#
# [873 rows x 1 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
en = OrdinalEncoder()
encode = en.fit_transform(x_train)

# %% [markdown]
# * 2. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
en = LabelEncoder()
encode = en.fit_transform(x_train)
pd.DataFrame(encode, columns=['TypeName'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      TypeName
# 0           4
# 1           7
# 2          10
# 3           4
# 4           7
# ..        ...
# 868         0
# 869         2
# 870         0
# 871         9
# 872         7
#
# [873 rows x 1 columns]

# %% [markdown]
# * 3. Onehot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
en1 = OneHotEncoder()
encode = en1.fit_transform(x_train)
pd.DataFrame(encode, columns=['TypeName'])
# Out:
#            TypeName
# 0       (0, 4)\t1.0
# 1       (0, 7)\t1.0
# 2      (0, 10)\t1.0
# 3       (0, 4)\t1.0
# 4       (0, 7)\t1.0
# ..              ...
# 868     (0, 0)\t1.0
# 869     (0, 2)\t1.0
# 870     (0, 0)\t1.0
# 871     (0, 9)\t1.0
# 872     (0, 7)\t1.0
#
# [873 rows x 1 columns]
