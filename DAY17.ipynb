# %%
import pandas as pd

# %%
df = pd.read_csv('boston.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# **classification**

# %%
import numpy as np
x,y = make_classification(n_samples = 100 , n_features = 2 ,n_informative = 1,
                          n_redundant = 1 , n_classes = 2 , n_clusters_per_class = 1 ,
                          random_state = 41, hypercube = False , class_sep = 10)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[: , 0] ,  x[: , 1] ,c=y, cmap = 'summer',s=100)

# %%
import numpy as np

# %%
def step (z):
    return 1 if z>0 else 0

# %%
def perceptron(x,y):
    x = np.insert(x,0,1,axis = 1)
    weights = np.ones(x.shape[1])
    ir = 0.1

    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(x[j] , weights))
        weights = weights +ir*(y[j] - y_hat) * x[j]
    return weights[0],weights[1:]

# %%
intercept_ , coef_ = perceptron(x,y)

# %%
m = -(coef_[0]/ coef_[1])
b = -(intercept_/coef_[1])

# %%
x_inp = np.linspace(-3,3,100)
y_inp = m*x_inp + b

# %%
plt.figure(figsize = (10,6))
plt.plot(x_inp , y_inp , color = 'red' , linewidth = 1)
plt.scatter(x[:,0] , x[:,1] , c=y , cmap='winter' , s =100)
plt.ylim(-3,2)
plt.show()

# %%
**

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
df = pd.DataFrame(data.data , columns = data.feature_names)

# %%
data.data
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
df['target'] = data.target

# %%
x = df.drop(columns= ['target'])
y = df.target
# Split the data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42, stratify = y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_train)
xt_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
ior = LogisticRegression()

# %%
from sklearn.decomposition import PCA

# %%
pc = PCA(n_components = 2)
X = pc.fit_transform(x_scaled)
xt = pc.transform(xt_scaled)
ior.fit(X,y_train)
# Out:
# LogisticRegression()

# %%
pd.DataFrame(xt_scaled)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.104399  0.727166  0.079100 -0.213272  1.298405  2.367121  1.527572
# 1   -0.313857  0.320029 -0.340729 -0.386575  1.328407 -0.511366 -0.701244
# 2   -0.632350 -0.440850 -0.644886 -0.633142  2.003459 -0.582479 -0.358151
# 3    1.436415  1.545890  1.556197  1.415893  1.928454  1.425200  1.292947
# 4    0.110799  0.471315  0.106145 -0.007603 -0.101203 -0.068926  0.392527
# ..        ...       ...       ...       ...       ...       ...       ...
# 166 -0.305250 -0.205022 -0.378176 -0.373629 -0.446980 -1.228689 -0.771754
# 167 -1.496583 -0.856886 -1.454584 -1.205718 -0.964520 -0.490914 -0.506542
# 168  0.690397 -0.233944  0.620008  0.551144  0.080311 -0.346436 -0.366381
# 169 -0.190478  0.064178 -0.243781 -0.251228 -0.398226 -0.755477 -0.366872
# 170 -0.345420 -0.810166 -0.317012 -0.394813 -1.320797 -0.137788  0.283199
#
#            7         8         9   ...        20        21        22  \
# ...

# %%
ior.coef_[0]
# Out:
# array([-1.8471655 ,  1.00624861])

# %%
m = -1*(ior.coef_[0][0]/ ior.coef_[0][1])
b = -1*(ior.intercept_/ior.coef_[0][1])

# %%
x_inp1 = np.linspace(x_scaled[:,0].min() - 1,x_scaled[:,0].max() + 1,100)
y_inp1 = m*x_inp1+ b

# %%
x_train.iloc[: ,0]
# Out:
# 469    11.620
# 561    11.200
# 443    10.570
# 362    12.760
# 271    11.290
#         ...
# 184    15.280
# 300    19.530
# 220    13.650
# 230    17.050
# 176     9.904
# Name: mean radius, Length: 398, dtype: float64

# %%
y_test[:399].size
# Out:
# 171

# %%
plt.plot(x_inp1, y_inp1 , color = 'black' , linewidth = 1)
plt.scatter(xt[: , 0], xt[:,1] ,c=y_test, cmap='winter' , s =100)
plt.show()
